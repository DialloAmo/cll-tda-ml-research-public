# %% [markdown]
# # Survival analysis baseline
#
# **Objectif :** Construire une baseline de survie si l’endpoint est temporel : time-to-first-treatment, progression-free survival ou overall survival.
#
# Ce notebook fait partie du pipeline CLL TDA ML research.

# %% [markdown]
# ## Plan du notebook
#
# 1. Préparation des données time-to-event
# 2. Courbes de Kaplan-Meier
# 3. Modèle de Cox
# 4. Random Survival Forest si disponible
# 5. C-index et Brier score
# 6. Interprétation clinique

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_DIR = PROJECT_ROOT / 'data'
RESULTS_DIR = PROJECT_ROOT / 'results'

PROJECT_ROOT

# %% [markdown]
# ## Préparation des données time-to-event

# %%
# TODO

# %% [markdown]
# ## Courbes de Kaplan-Meier

# %%
# TODO

# %% [markdown]
# ## Modèle de Cox

# %%
# TODO

# %% [markdown]
# ## Random Survival Forest si disponible

# %%
# TODO

# %% [markdown]
# ## C-index et Brier score

# %%
# TODO

# %% [markdown]
# ## Interprétation clinique

# %%
# TODO
