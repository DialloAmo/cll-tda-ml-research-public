# %% [markdown]
# # Endpoint definition and cohort selection
#
# **Objectif :** Définir la cohorte d’analyse, les critères d’inclusion/exclusion et l’endpoint principal : time-to-first-treatment, progression, réponse thérapeutique ou survie.
#
# Ce notebook fait partie du pipeline CLL TDA ML research.

# %% [markdown]
# ## Plan du notebook
#
# 1. Chargement des données nettoyées
# 2. Définition de la cohorte
# 3. Analyse des variables cliniques disponibles
# 4. Définition de l’endpoint principal
# 5. Création des labels ou variables de survie
# 6. Sauvegarde de la cohorte analytique

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_DIR = PROJECT_ROOT / 'data'
RESULTS_DIR = PROJECT_ROOT / 'results'

PROJECT_ROOT

# %% [markdown]
# ## Chargement des données nettoyées

# %%
# TODO

# %% [markdown]
# ## Définition de la cohorte

# %%
# TODO

# %% [markdown]
# ## Analyse des variables cliniques disponibles

# %%
# TODO

# %% [markdown]
# ## Définition de l’endpoint principal

# %%
# TODO

# %% [markdown]
# ## Création des labels ou variables de survie

# %%
# TODO

# %% [markdown]
# ## Sauvegarde de la cohorte analytique

# %%
# TODO
