# %% [markdown]
# # Geometric patient space with PCA and UMAP
#
# **Objectif :** Représenter les patients comme des points dans un espace biologique afin d’identifier gradients, sous-groupes et régions associées à des marqueurs cliniques.
#
# Ce notebook fait partie du pipeline CLL TDA ML research.

# %% [markdown]
# ## Plan du notebook
#
# 1. Construction de la matrice patient-feature
# 2. Standardisation
# 3. PCA
# 4. UMAP
# 5. Coloration par IGHV, TP53, del(17p), Rai/Binet ou endpoint
# 6. Interprétation géométrique préliminaire

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_DIR = PROJECT_ROOT / 'data'
RESULTS_DIR = PROJECT_ROOT / 'results'

PROJECT_ROOT

# %% [markdown]
# ## Construction de la matrice patient-feature

# %%
# TODO

# %% [markdown]
# ## Standardisation

# %%
# TODO

# %% [markdown]
# ## PCA

# %%
# TODO

# %% [markdown]
# ## UMAP

# %%
# TODO

# %% [markdown]
# ## Coloration par IGHV, TP53, del(17p), Rai/Binet ou endpoint

# %%
# TODO

# %% [markdown]
# ## Interprétation géométrique préliminaire

# %%
# TODO
