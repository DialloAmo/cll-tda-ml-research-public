# %% [markdown]
# # Hybrid TDA + Machine Learning models
#
# **Objectif :** Combiner les features classiques et les features topologiques pour tester si la TDA améliore la stratification clinique.
#
# Ce notebook fait partie du pipeline CLL TDA ML research.

# %% [markdown]
# ## Plan du notebook
#
# 1. Chargement des features classiques
# 2. Chargement des features TDA
# 3. Concaténation des représentations
# 4. Modèle ML classique seul
# 5. Modèle TDA seul
# 6. Modèle hybride classique + TDA
# 7. Comparaison statistique

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_DIR = PROJECT_ROOT / 'data'
RESULTS_DIR = PROJECT_ROOT / 'results'

PROJECT_ROOT

# %% [markdown]
# ## Chargement des features classiques

# %%
# TODO

# %% [markdown]
# ## Chargement des features TDA

# %%
# TODO

# %% [markdown]
# ## Concaténation des représentations

# %%
# TODO

# %% [markdown]
# ## Modèle ML classique seul

# %%
# TODO

# %% [markdown]
# ## Modèle TDA seul

# %%
# TODO

# %% [markdown]
# ## Modèle hybride classique + TDA

# %%
# TODO

# %% [markdown]
# ## Comparaison statistique

# %%
# TODO
