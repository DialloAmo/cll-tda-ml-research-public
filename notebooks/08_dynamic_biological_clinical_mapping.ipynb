# %% [markdown]
# # Dynamic biological-clinical mapping
#
# **Objectif :** Construire la cartographie dynamique reliant trajectoires biologiques et trajectoires cliniques, cœur scientifique ambitieux du projet.
#
# Ce notebook fait partie du pipeline CLL TDA ML research.

# %% [markdown]
# ## Plan du notebook
#
# 1. Définition des trajectoires biologiques
# 2. Définition des trajectoires cliniques
# 3. Projection dans l’espace géométrique
# 4. Analyse des transitions ou gradients
# 5. Lien entre régions géométriques et évolution clinique
# 6. Interprétation de l’hétérogénéité de la LLC

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_DIR = PROJECT_ROOT / 'data'
RESULTS_DIR = PROJECT_ROOT / 'results'

PROJECT_ROOT

# %% [markdown]
# ## Définition des trajectoires biologiques

# %%
# TODO

# %% [markdown]
# ## Définition des trajectoires cliniques

# %%
# TODO

# %% [markdown]
# ## Projection dans l’espace géométrique

# %%
# TODO

# %% [markdown]
# ## Analyse des transitions ou gradients

# %%
# TODO

# %% [markdown]
# ## Lien entre régions géométriques et évolution clinique

# %%
# TODO

# %% [markdown]
# ## Interprétation de l’hétérogénéité de la LLC

# %%
# TODO
