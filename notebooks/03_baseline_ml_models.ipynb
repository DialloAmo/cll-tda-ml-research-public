# %% [markdown]
# # Classical Machine Learning baselines
#
# **Objectif :** Construire les modèles de référence avant d’ajouter la TDA : régression logistique, Random Forest, SVM, XGBoost ou LightGBM selon les données disponibles.
#
# Ce notebook fait partie du pipeline CLL TDA ML research.

# %% [markdown]
# ## Plan du notebook
#
# 1. Chargement des features classiques
# 2. Train/test split ou validation croisée
# 3. Régression logistique
# 4. Random Forest
# 5. SVM
# 6. XGBoost ou LightGBM
# 7. Comparaison des performances

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_DIR = PROJECT_ROOT / 'data'
RESULTS_DIR = PROJECT_ROOT / 'results'

PROJECT_ROOT

# %% [markdown]
# ## Chargement des features classiques

# %%
# TODO

# %% [markdown]
# ## Train/test split ou validation croisée

# %%
# TODO

# %% [markdown]
# ## Régression logistique

# %%
# TODO

# %% [markdown]
# ## Random Forest

# %%
# TODO

# %% [markdown]
# ## SVM

# %%
# TODO

# %% [markdown]
# ## XGBoost ou LightGBM

# %%
# TODO

# %% [markdown]
# ## Comparaison des performances

# %%
# TODO
