# %% [markdown]
# # Interpretability, robustness and final figures
#
# **Objectif :** Produire les analyses finales : SHAP, permutation importance, robustesse, ablation study et figures propres pour rapport ou article.
#
# Ce notebook fait partie du pipeline CLL TDA ML research.

# %% [markdown]
# ## Plan du notebook
#
# 1. Importance des variables
# 2. SHAP values
# 3. Permutation importance
# 4. Ablation study sans TDA / avec TDA
# 5. Validation croisée répétée
# 6. Figures finales
# 7. Tableaux de résultats

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_DIR = PROJECT_ROOT / 'data'
RESULTS_DIR = PROJECT_ROOT / 'results'

PROJECT_ROOT

# %% [markdown]
# ## Importance des variables

# %%
# TODO

# %% [markdown]
# ## SHAP values

# %%
# TODO

# %% [markdown]
# ## Permutation importance

# %%
# TODO

# %% [markdown]
# ## Ablation study sans TDA / avec TDA

# %%
# TODO

# %% [markdown]
# ## Validation croisée répétée

# %%
# TODO

# %% [markdown]
# ## Figures finales

# %%
# TODO

# %% [markdown]
# ## Tableaux de résultats

# %%
# TODO
